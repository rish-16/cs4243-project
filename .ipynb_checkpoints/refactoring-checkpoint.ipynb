# %% [markdown]
# # Code Refactoring

# %% [markdown]
# ### Project Components
# 1. Dataset collection
# 2. Dataset analysis
# 3. Model training
# 4. Hyperparameter tuning
# 5. Model evaluation
# 6. Error Analysis
# 7. Model analysis

# %% [markdown]
# ### Dataset Collection

# %%
from dataset_collection import *

# %%
ad = get_all_datasets()
# Out:
# Loaded dataset at 'dataset/cifar/cifar.npy'.
# Loaded dataset at 'dataset/sketchy/sketchy_real.npy'.
# Loaded dataset at 'dataset/sketchy/sketchy_doodle.npy'.
# Loaded dataset at 'dataset/tuberlin/tuberlin.npy'.
# Loaded dataset at 'dataset/google_images/google_doodles.npy'.
# Loaded dataset at 'dataset/google_images/google_real.npy'.

# %%
dd = get_doodle_datasets()
# Out:
# Loaded dataset at 'dataset/quickdraw/quickdraw.npy'.
# Loaded dataset at 'dataset/sketchy/sketchy_doodle.npy'.
# Loaded dataset at 'dataset/tuberlin/tuberlin.npy'.
# Loaded dataset at 'dataset/google_images/google_doodles.npy'.

# %%
rd = get_real_datasets()
# Out:
# Loaded dataset at 'dataset/cifar/cifar.npy'.
# Loaded dataset at 'dataset/sketchy/sketchy_real.npy'.
# Loaded dataset at 'dataset/google_images/google_real.npy'.

# %%
cdd = collapse_datasets(dd)
crd = collapse_datasets(rd)

# %%
sketchy_pairs = get_sketchy_pairs()
# Out:
# Loaded dataset at 'dataset/sketchy/sketchy_pairs.npy'.

# %% [markdown]
# ### Dataset Analysis

# %%
from dataset_analysis import *

# %%
plot_dataset_dist(cdd, "Combined Doodle Dataset")

# %%
plot_dataset_mean(dd['sketchy_doodle'])

# %% [markdown]
# ### Model Training

# %%
from model_training import *

# %%
doodle_dataloader = DataLoader(DoodleDataset(train=True), batch_size=32, shuffle=True)
x, y = next(iter(doodle_dataloader))
# Out:
# Loaded dataset at 'dataset/sketchy/sketchy_doodle.npy'.
# Loaded dataset at 'dataset/tuberlin/tuberlin.npy'.
# Loaded dataset at 'dataset/google_images/google_doodles.npy'.

# %%
mlp = MLP(n_input=64*64)
pred, feat = mlp(x, return_feat=True)
pred.shape, feat.shape, mlp
# Out:
# (torch.Size([32, 9]),
#  torch.Size([32, 64]),
#  MLP(
#    (act): LeakyReLU(negative_slope=0.01)
#    (dropout): Dropout(p=0.1, inplace=False)
#    (layers): Sequential(
#      (0): Linear(in_features=4096, out_features=64, bias=False)
#      (1): LeakyReLU(negative_slope=0.01)
#      (2): Dropout(p=0.1, inplace=False)
#      (3): Linear(in_features=64, out_features=9, bias=False)
#    )
#  ))

# %%
cnn = CNN(n_channels=1, n_filters=32, n_conv=3, n_linear=3)
pred, feat = cnn(x, return_feat=True)
pred.shape, feat.shape, cnn
# Out:
# (torch.Size([32, 9]),
#  torch.Size([32, 64]),
#  CNN(
#    (p): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#    (flatten): Flatten(start_dim=1, end_dim=-1)
#    (act): LeakyReLU(negative_slope=0.01)
#    (dropout): Dropout(p=0.1, inplace=False)
#    (layers): Sequential(
#      (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#      (2): LeakyReLU(negative_slope=0.01)
#      (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (4): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#      (5): LeakyReLU(negative_slope=0.01)
#      (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (7): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#      (8): LeakyReLU(negative_slope=0.01)
# ...

# %%
class CNNCL(nn.Module):
    def __init__(self,
                 n_classes=9,
                 n_filters=32,
                 k_size=3,
                 p_size=2,
                 n_conv=2,
                 n_linear=2,
                 dropout=0.1,
                 c=1,
                 t=0.1):
        super(CNNCL, self).__init__()
        self.c = c
        self.t = t
        self.dmodel = CNN(1, n_classes, n_filters, k_size, p_size, n_conv, n_linear, dropout)
        self.rmodel = CNN(3, n_classes, n_filters, k_size, p_size, n_conv, n_linear, dropout)
    def forward(self, x1, x2):
        pred1, feat1 = self.dmodel(x1, return_feat=True)
        pred2, feat2 = self.rmodel(x2, return_feat=True)
        return pred1, feat1, pred2, feat2
    def loss(self, pred1, feat1, pred2, feat2, y):
        xent = nn.CrossEntropyLoss()
        xent_loss1 = xent(pred1, y)
        xent_loss2 = xent(pred2, y)
        feat3 = torch.cat((feat1, feat2), axis=0)
        y3 = torch.cat((y, y), axis=0)
        cont_loss = compute_contrastive_loss_from_feats(feat3, y3, self.t)
        loss = xent_loss1 + xent_loss2 + self.c * cont_loss
        return loss

# %%
contrastive_dataloader = DataLoader(ContrastiveDataset(train=True), batch_size=32, shuffle=True)
x1, x2, y = next(iter(contrastive_dataloader))
# Out:
# Loaded dataset at 'dataset/sketchy/sketchy_doodle.npy'.
# Loaded dataset at 'dataset/tuberlin/tuberlin.npy'.
# Loaded dataset at 'dataset/google_images/google_doodles.npy'.
# Loaded dataset at 'dataset/cifar/cifar.npy'.
# Loaded dataset at 'dataset/sketchy/sketchy_real.npy'.
# Loaded dataset at 'dataset/google_images/google_real.npy'.

# %%
cnncl = CNNCL()
pred1, feat1, pred2, feat2 = cnncl(x1, x2)
pred1.shape, feat1.shape, pred2.shape, feat2.shape
# Out:
# C:\Users\notes\anaconda3\envs\cs4243\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (torch.Size([32, 9]),
#  torch.Size([32, 64]),
#  torch.Size([32, 9]),
#  torch.Size([32, 64]))

# %%
class Trainer:
    def __init__(self, model, trainset, valset, epochs, bs):
        self.model = model
        self.contrastive = isinstance(trainset, ContrastiveDataset)
        self.train_loader = DataLoader(trainset, batch_size=bs)
        self.val_loader = DataLoader(valset, batch_size=len(valset))
        self.epochs = epochs
        self.history = None
        self.optimizer = torch.optim.AdamW(params=list(self.model.parameters()), lr=1e-3, weight_decay=3e-4)
        self.xent = nn.CrossEntropyLoss()
        self.scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(self.optimizer, T_max=epochs)
        
    def track(self, metric, value):
        if self.history is None:
            self.history = {
                "epoch": [],
                "train_loss": [],
                "train_acc": [],
                "val_loss": [],
                "val_acc": []}
        assert metric in self.history
        self.history[metric].append(value)
    def train_epoch(self):
        avg_loss = AverageMeter()
        avg_acc = AverageMeter()
        if not self.contrastive:
            for i, (x, y) in enumerate(self.train_loader):
                pred = self.model(x)
                loss = self.xent(pred, y)
                loss.backward()
                self.optimizer.step()
                self.optimizer.zero_grad()
                acc = compute_accuracy(pred, y)
                avg_loss.update(loss.item())
                avg_acc.update(acc)
        else:
            for i, (x1, x2, y) in enumerate(self.train_loader):
                pred1, feat1, pred2, feat2 = self.model(x1, x2)
                loss = self.model.loss(pred1, feat1, pred2, feat2, y)
                loss.backward()
                self.optimizer.step()
                self.optimizer.zero_grad()
                acc = (compute_accuracy(pred1, y) + compute_accuracy(pred2, y)) / 2
                avg_loss.update(loss.item())
                avg_acc.update(acc)
        return avg_acc.avg, avg_loss.avg
    def evaluate_epoch(self):
        if not self.contrastive:
            x, y = next(iter(self.val_loader))
            with torch.no_grad():
                pred, feat = self.model(x, return_feat=True)
                loss = self.xent(pred, y)
            _, yhat = torch.max(pred, 1)
            acc = compute_accuracy(pred, y)
        else:
            x1, x2, y = next(iter(self.val_loader))
            with torch.no_grad():
                pred1, feat1, pred2, feat2 = self.model(x1, x2)
                loss = self.model.loss(pred1, feat1, pred2, feat2, y)
            acc = (compute_accuracy(pred1, y) +  compute_accuracy(pred2, y)) / 2
        return acc, loss.item()
    def train(self, verbose=False):
        for epoch in range(self.epochs):
            train_acc, train_loss = self.train_epoch()
            val_acc, val_loss = self.evaluate_epoch()
            self.track("epoch", epoch)
            self.track("train_loss", train_loss)
            self.track("train_acc", train_acc)
            self.track("val_loss", val_loss)
            self.track("val_acc", val_acc)
            if verbose:
                print(f"Epoch: {epoch} | Train Loss: {train_loss:.3f} | Train Acc: {train_acc:.3f} | Val Loss: {val_loss:.3f} | Val Acc: {val_acc:.3f}")
        return self.history

# %%
import torchvision

# %%
torchvision.models.resnet18(pretrained=False)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
train_dataset = ContrastiveDataset(train=True)
val_dataset = ContrastiveDataset(train=False)
# Out:
# Loaded dataset at 'dataset/sketchy/sketchy_doodle.npy'.
# Loaded dataset at 'dataset/tuberlin/tuberlin.npy'.
# Loaded dataset at 'dataset/google_images/google_doodles.npy'.
# Loaded dataset at 'dataset/cifar/cifar.npy'.
# Loaded dataset at 'dataset/sketchy/sketchy_real.npy'.
# Loaded dataset at 'dataset/google_images/google_real.npy'.
# Loaded dataset at 'dataset/sketchy/sketchy_doodle.npy'.
# Loaded dataset at 'dataset/tuberlin/tuberlin.npy'.
# Loaded dataset at 'dataset/google_images/google_doodles.npy'.
# Loaded dataset at 'dataset/cifar/cifar.npy'.
# Loaded dataset at 'dataset/sketchy/sketchy_real.npy'.
# Loaded dataset at 'dataset/google_images/google_real.npy'.

# %%
trainer = Trainer(CNNCL(), train_dataset, val_dataset, 3, 32)
history = trainer.train(verbose=True)
# Out:
# Epoch: 0 | Train Loss: 5.044 | Train Acc: 0.415 | Val Loss: 4.085 | Val Acc: 0.621
# Epoch: 1 | Train Loss: 3.317 | Train Acc: 0.697 | Val Loss: 2.976 | Val Acc: 0.769
# Epoch: 2 | Train Loss: 2.566 | Train Acc: 0.803 | Val Loss: 2.486 | Val Acc: 0.828

# %%
history

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from hyperparameter_tuning import *

# %%
class Tuner:
    def __init__(self, param_ranges):
        self.param_ranges = param_ranges
        self.best_param = {p: None for p in param_ranges}
    def set_best_param(self, p, v):
        self.best_param[p] = v
    def init_param(self, p, v):
        current_param = self.best_param.copy()
        current_param[p] = v
        for p, v in current_param.items():
            if v is None:
                current_param[p] = self.param_ranges[p][0]
        return current_param
    def tune(self):
        for param, values in self.param_ranges.items():
            for p in values:
                curr_param = self.init_param(param, p)

# %%
param_ranges = {
    'n_linear': [1,2,3],
}
tuner = Tuner(param_ranges)
tuner.tune()

# %% [markdown]
# ### Model Evaluation

# %%
from model_evaluation import *
from models import *

# %%
accuracy = evaluate_model(DoodleMLP(64*64, 128, 9, dropout=0.2),
                          "mlp_trained/14_model1.pt",
                          DoodleDataset(train=False),
                          classes,
                          report=True)
# Out:
#                accuracy
#
#     airplane       0.75
#         bird       0.02
#          car       0.02
#          cat       0.03
#          dog       0.02
#         frog       0.03
#        horse       0.01
#         ship       0.02
#        truck       0.03
#               precision    recall  f1-score   support
#
#     airplane       0.76      0.75      0.76       209
#         bird       0.02      0.02      0.02       208
#          car       0.02      0.02      0.02       215
#          cat       0.04      0.03      0.03       210
#          dog       0.03      0.02      0.02       210
#         frog       0.02      0.03      0.02       195
#        horse       0.01      0.01      0.01       213
#         ship       0.01      0.02      0.01        93
#        truck       0.06      0.03      0.04       208
#
#     accuracy                           0.11      1761
#    macro avg       0.11      0.10      0.10      1761
# weighted avg       0.11      0.11      0.11      1761

# %%
accuracy = evaluate_model(RealMLP(64*64*3, 512, 9, dropout=0.2),
                          "mlp_trained/14_model2.pt",
                          RealDataset(train=False),
                          classes=classes,
                          report=False)
# Out:
#                accuracy
#
#     airplane       0.67
#         bird       0.02
#          car       0.01
#          cat       0.19
#          dog       0.06
#         frog       0.03
#        horse       0.05
#         ship       0.02
#        truck       0.05

# %%
s = Similarity()
sims = s.evaluate(DoodleMLP(64*64, 128, 9, dropout=0.2), "mlp_trained/14_model1.pt",
                  RealMLP(64*64*3, 512, 9, dropout=0.2), "mlp_trained/14_model2.pt")
# Out:
#              similarity
#
#     airplane       0.20
#         bird       0.19
#          car       0.19
#          cat       0.16
#          dog       0.08
#         frog       0.13
#        horse       0.15
#         ship       0.11
#        truck        nan
#
#    aggregate       0.15

# %% [markdown]
# ### Error Analysis

# %%
from error_analysis import *
from models import *

# %%
analyse_errors(DoodleMLP(64*64, 128, 9, dropout=0.2),
               "mlp_trained/14_model1.pt",
               DoodleDataset(train=False),
               classes,
               n=10)

# %%
analyse_errors(RealMLP(64*64*3, 512, 9, dropout=0.2),
               "mlp_trained/14_model2.pt",
               RealDataset(train=False),
               classes,
               n=10)

# %% [markdown]
# ### Model Analysis

# %%
from model_analysis import *
from models import *

# %%
tsne_d = Tsne(DoodleDataset(train=False))
tsne_d.visualise(DoodleMLP(64*64, 128, 9, dropout=0.2), "mlp_trained/14_model1.pt")
# Out:
# Loaded dataset at 'dataset/sketchy/sketchy_doodle.npy'.
# Loaded dataset at 'dataset/tuberlin/tuberlin.npy'.
# Loaded dataset at 'dataset/google_images/google_doodles.npy'.

# %%
tsne_r = Tsne(RealDataset(train=False))
tsne_r.visualise(RealMLP(64*64*3, 512, 9, dropout=0.2), "mlp_trained/14_model2.pt")
# Out:
# Loaded dataset at 'dataset/cifar/cifar.npy'.
# Loaded dataset at 'dataset/sketchy/sketchy_real.npy'.
# Loaded dataset at 'dataset/google_images/google_real.npy'.

# %%
from pytorch_grad_cam import GradCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM, FullGrad
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image

def plot_cam_img(img, tensor, model, layer, target):
    cam = GradCAM(model, [layer])
    overlay = cam(torch.unsqueeze(tensor, axis=0), [ClassifierOutputTarget(target)])[0,:]
    vis = show_cam_on_image(img/255, overlay, use_rgb=True)
    plt.imshow(vis)
    plt.show()

# %%
rmodel = load_model(V2ConvNet(3, 9), "v2cnn_trained/24_model2.pt").eval()
d = RealDataset(train=False)
dl = DataLoader(d, batch_size=len(d), shuffle=False)
x, y = next(iter(dl))
# Out:
# Loaded dataset at 'dataset/cifar/cifar.npy'.
# Loaded dataset at 'dataset/sketchy/sketchy_real.npy'.
# Loaded dataset at 'dataset/google_images/google_real.npy'.

# %%
layers = list(rmodel.children())

# %%
convs = []
for layer in rmodel.children():
    if isinstance(layer, nn.Conv2d):
        convs.append(layer)
    elif isinstance(layer, nn.Sequential):
        for l in layer.children():
            if isinstance(l, nn.Conv2d):
                convs.append(l)
            elif isinstance(l, nn.Sequential):
                for la in l.children():
                    if isinstance(la, nn.Conv2d):
                        convs.append(la)
                    elif isinstance(la, nn.Sequential):
                        raise Exception()
# Out:
# [Conv2d(3, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1)),
#  Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1)),
#  Conv2d(128, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1)),
#  Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1)),
#  Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1)),
#  Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1)),
#  Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1)),
#  Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))]

# %%
np.random.choice(20, 10)
# Out:
# array([0])

# %%
i = 4
for layer in convs:
    plot_cam(d.X[i], x[i], rmodel, layer, y[i].item())

# %%
i = 0
for n in range(len(rmodel.layers)):
    print(rmodel.layers[n])
    plot_cam(d.X[i], x[i], rmodel, rmodel.layers[n], y[i].item())
# Out:
# Sequential(
#   (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
# )
# Sequential(
#   (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
# )
# Sequential(
#   (0): Conv2d(128, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
# )
# Sequential(
#   (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1))
#   (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
# )
# Sequential(
#   (0): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
